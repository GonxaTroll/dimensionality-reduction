# %%
"""
Example: Basic PCA analysis with preprocessing and visualization using PCAModel.

This example demonstrates how to use the dimensionality_reduction package
via the PCAModel class for preprocessing, PCA, and visualization.
"""

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

from dimensionality_reduction import PCAModel


def main():
    """Run PCA example on Iris dataset using PCAModel."""
    # Load the Iris dataset
    iris = load_iris()
    df = pd.DataFrame(iris.data, columns=iris.feature_names)
    y = iris.target
    
    print("=" * 60)
    print("BASIC PCA ANALYSIS - IRIS DATASET")
    print("=" * 60)
    print(f"\nOriginal data shape: {df.shape}")
    print(f"Feature names: {list(df.columns)}\n")
    
    # Create and fit the PCA model
    print("Fitting PCA model with standardization...")
    model = PCAModel(df).fit(n_components=4, preprocessing="standardize")
    print(f"PCA fitted with {model.n_components} components")
    print(f"Explained variance ratio: {model.explained_variance_ratio_}")
    
    # Step 2: Visualize results
    print("\nCreating visualizations...")
    
    # Plot loadings for first component
    print("  - Plotting loadings (component 1)...")
    fig1 = model.plot_loadings(component_idx=0, figsize=(10, 6))
    plt.show()
    # plt.savefig("pca_loadings_component1.png", dpi=150, bbox_inches='tight')
    plt.close(fig1)
    print("    Saved: pca_loadings_component1.png")
    
    # Plot data in PC space
    print("  - Plotting scores (PC1 vs PC2)...")
    fig2 = model.plot_scores(pc1=1, pc2=2, score_color=y, figsize=(10, 8))
    plt.show()
    # plt.savefig("pca_scores.png", dpi=150, bbox_inches='tight')
    plt.close(fig2)
    print("    Saved: pca_scores.png")
    
    # Plot variance explained
    print("  - Plotting variance explained...")
    fig3 = model.plot_variance_explained(figsize=(10, 6))
    plt.show()
    # plt.savefig("pca_variance_explained.png", dpi=150, bbox_inches='tight')
    plt.close(fig3)
    print("    Saved: pca_variance_explained.png")
    
    # Print summary
    print("\n" + "=" * 60)
    print("SUMMARY")
    print("=" * 60)
    print(f"Total variance explained by 2 components: {sum(model.explained_variance_ratio_[:2]):.2%}")
    print(f"Total variance explained by all components: {sum(model.explained_variance_ratio_):.2%}")
    print(f"\nPreprocessing method: {model.preprocessing}")
    print(f"Number of samples: {model.n_samples}")
    print(f"Number of features: {model.n_features}")
    
    print("\nExample completed successfully!")


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# BASIC PCA ANALYSIS - IRIS DATASET
# ============================================================
#
# Original data shape: (150, 4)
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#
# Fitting PCA model with standardization...
# PCA fitted with 4 components
# Explained variance ratio: [0.72962445 0.22850762 0.03668922 0.00517871]
#
# Creating visualizations...
#   - Plotting loadings (component 1)...
#     Saved: pca_loadings_component1.png
#   - Plotting scores (PC1 vs PC2)...
#     Saved: pca_scores.png
#   - Plotting variance explained...
# Selected components (above expected variance): 1
#     Saved: pca_variance_explained.png
#
# ============================================================
# SUMMARY
# ============================================================
# Total variance explained by 2 components: 95.81%
# Total variance explained by all components: 100.00%
#
# Preprocessing method: standardize
# Number of samples: 150
# Number of features: 4
#
# Example completed successfully!

# %%
"""
Example: Advanced PCA analysis with outlier detection using PCAModel.

This example demonstrates comprehensive PCA analysis including visualization,
outlier detection, and diagnostics using T² and SPE statistics via PCAModel.
"""

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

from dimensionality_reduction import PCAModel # pylint: disable=E0401


def main():
    """Run comprehensive PCA analysis on Iris dataset using PCAModel."""
    # Load the Iris dataset
    iris = load_iris(as_frame=True)

    df = iris.data # pylint: disable=E1101
    y = iris.target # pylint: disable=E1101

    print("=" * 60)
    print("COMPREHENSIVE PCA ANALYSIS - IRIS DATASET")
    print("=" * 60)
    print(f"\nOriginal data shape: {df.shape}")
    print(f"Number of samples: {df.shape[0]}")
    print(f"Number of features: {df.shape[1]}")
    print(f"Feature names: {list(df.columns)}\n")

    # Create and fit the PCA model
    print("=" * 60)
    print("STEP 1: MODEL FITTING")
    print("=" * 60)
    model = PCAModel(df).fit(n_components=4, preprocessing="standardize")
    print(f"PCA fitted with {model.n_components} components")
    print(f"Explained variance ratio: {model.explained_variance_ratio_}")
    print(f"Cumulative variance: {model.explained_variance_ratio_.cumsum()}")

    # Step 2: Component selection
    print("\n" + "=" * 60)
    print("STEP 2: COMPONENT SELECTION")
    print("=" * 60)
    kaiser_components = model.kaiser_components()
    selected_components = len(kaiser_components)
    print(f"Kaiser criterion suggests {len(kaiser_components)} components: {kaiser_components}")

    # Plot variance explained
    fig1 = model.plot_variance_explained(figsize=(10, 6))
    plt.show()
    plt.close(fig1)
    print("Saved: advanced_pca_variance_explained.png")

    # Plot eigenvalues
    fig2 = model.plot_eigenvalues(figsize=(10, 6))
    plt.show()
    plt.close(fig2)
    print("Saved: advanced_pca_eigenvalues.png")

    # Step 3: Score visualization
    print("\n" + "=" * 60)
    print("STEP 3: SCORE PLOTS")
    print("=" * 60)
    fig3 = model.plot_scores(pc1=1, pc2=2, score_color=y, figsize=(10, 8))
    plt.show()
    plt.close(fig3)
    print("Saved: advanced_pca_scores.png")

    # Step 4: Loadings visualization
    print("\n" + "=" * 60)
    print("STEP 4: LOADINGS PLOTS")
    print("=" * 60)
    fig4 = model.plot_loadings_2d(pc1=1, pc2=2, draw_labels=True, 
                                   color_by="contrib", figsize=(10, 8))
    plt.show()
    plt.close(fig4)
    print("Saved: advanced_pca_loadings_2d.png")

    # Step 5: Outlier detection - Hotelling T²
    print("\n" + "=" * 60)
    print("STEP 5: OUTLIER DETECTION - HOTELLING T²")
    print("=" * 60)
    t2_vals, t2_95, t2_99 = model.t2(selected_components, plot=True, figsize=(12, 6))
    plt.show()
    plt.close()
    print("Saved: advanced_pca_t2_hotelling.png")

    # Identify T² outliers
    t2_outliers, _ = model.outliers_from_t2(selected_components, alpha=0.99)
    if len(t2_outliers) > 0:
        print(f"T² outliers (99% confidence): {t2_outliers}")

    # Step 6: Outlier detection - SPE
    print("\n" + "=" * 60)
    print("STEP 6: OUTLIER DETECTION - SPE (Q-STATISTIC)")
    print("=" * 60)

    # SPE with chi-squared approximation
    spe_vals, spe_95, spe_99 = model.spe(selected_components, plot=True, figsize=(12, 6))
    plt.show()
    plt.close()
    print("Saved: advanced_pca_spe.png")

    # SPE with Jackson-Mudholkar approximation
    spe_jm_vals, spe_jm_95, spe_jm_99 = model.spe_jackson_mudholkar(
        selected_components, plot=True, figsize=(12, 6)
    )
    plt.show()
    plt.close()
    print("Saved: advanced_pca_spe_jackson_mudholkar.png")

    # Identify SPE outliers
    spe_outliers, _ = model.outliers_from_spe(selected_components, alpha=0.99)
    if len(spe_outliers) > 0:
        print(f"SPE outliers (99% confidence): {spe_outliers}")

    # Step 7: Variable contributions for outliers
    print("\n" + "=" * 60)
    print("STEP 7: VARIABLE CONTRIBUTIONS FOR OUTLIERS")
    print("=" * 60)

    # Combine all outliers
    all_outliers = sorted(set(t2_outliers) | set(spe_outliers))

    if len(all_outliers) > 0:
        print(f"Analyzing variable contributions for samples: {all_outliers[:5]}")

        # Plot contributions for first few outliers
        for idx in all_outliers[:3]:
            fig, _ = model.plot_contribs(indivs=idx, pc=2, figsize=(12, 6))
            plt.savefig(f"advanced_pca_contributions_sample_{idx}.png", 
                       dpi=150, bbox_inches='tight')
            plt.close(fig)
            print(f"Saved: advanced_pca_contributions_sample_{idx}.png")
    else:
        print("No significant outliers detected in this dataset.")

    # Step 8: Summary
    print("\n" + "=" * 60)
    print("SUMMARY")
    print("=" * 60)
    print(f"Components selected (Kaiser criterion): {selected_components}")
    print(f"Variance explained by selected components: "
          f"{model.explained_variance_ratio_[:selected_components].sum():.2%}")
    print("\nOutliers detected (99% confidence):")
    print(f"  - T²: {len(t2_outliers)} samples")
    print(f"  - SPE: {len(spe_outliers)} samples")
    print(f"  - Combined unique: {len(all_outliers)} samples")
    print(f"\nPreprocessing method: {model.preprocessing}")

    print("\n" + "=" * 60)
    print("ANALYSIS COMPLETED SUCCESSFULLY!")
    print("=" * 60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# COMPREHENSIVE PCA ANALYSIS - IRIS DATASET
# ============================================================
#
# Original data shape: (150, 4)
# Number of samples: 150
# Number of features: 4
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#
# ============================================================
# STEP 1: MODEL FITTING
# ============================================================
# PCA fitted with 4 components
# Explained variance ratio: [0.72962445 0.22850762 0.03668922 0.00517871]
# Cumulative variance: [0.72962445 0.95813207 0.99482129 1.        ]
#
# ============================================================
# STEP 2: COMPONENT SELECTION
# ============================================================
# First 1 components have eigenvalues > 1
# Kaiser criterion suggests 1 components: [2.93808505]
# Selected components (above expected variance): 1
# Saved: advanced_pca_variance_explained.png
# Saved: advanced_pca_eigenvalues.png
#
# ============================================================
# STEP 3: SCORE PLOTS
# ============================================================
# Saved: advanced_pca_scores.png
#
# ============================================================
# STEP 4: LOADINGS PLOTS
# ============================================================
# Saved: advanced_pca_loadings_2d.png
#
# ============================================================
# STEP 5: OUTLIER DETECTION - HOTELLING T²
# ============================================================
# Saved: advanced_pca_t2_hotelling.png
# Number of outliers detected: 0
#
# ============================================================
# STEP 6: OUTLIER DETECTION - SPE (Q-STATISTIC)
# ============================================================
# Saved: advanced_pca_spe.png
# Saved: advanced_pca_spe_jackson_mudholkar.png
# Number of outliers detected: 3
# SPE outliers (99% confidence): [ 15  60 131]
#
# ============================================================
# STEP 7: VARIABLE CONTRIBUTIONS FOR OUTLIERS
# ============================================================
# Analyzing variable contributions for samples: [np.int64(15), np.int64(60), np.int64(131)]
# Saved: advanced_pca_contributions_sample_15.png
# Saved: advanced_pca_contributions_sample_60.png
# Saved: advanced_pca_contributions_sample_131.png
#
# ============================================================
# SUMMARY
# ============================================================
# Components selected (Kaiser criterion): 1
# Variance explained by selected components: 72.96%
#
# Outliers detected (99% confidence):
#   - T²: 0 samples
#   - SPE: 3 samples
#   - Combined unique: 3 samples
#
# Preprocessing method: standardize
#
# ============================================================
# ANALYSIS COMPLETED SUCCESSFULLY!
# ============================================================

# %%
"""
Example: Advanced PCA analysis with outlier detection using PCAModel.

This example demonstrates comprehensive PCA analysis including visualization,
outlier detection, and diagnostics using T² and SPE statistics via PCAModel.
"""

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

from dimensionality_reduction import PCAModel # pylint: disable=E0401


def main():
    """Run comprehensive PCA analysis on Iris dataset using PCAModel."""
    # Load the Iris dataset
    iris = load_iris(as_frame=True)

    df = iris.data # pylint: disable=E1101
    y = iris.target # pylint: disable=E1101

    # Create and fit the PCA model
    model = PCAModel(df).fit(n_components=4, preprocessing="standardize")

    # Step 2: Component selection
    kaiser_components = model.kaiser_components()
    selected_components = len(kaiser_components)

    # Step 5: Outlier detection - Hotelling T²
    t2_vals, t2_95, t2_99 = model.t2(selected_components, plot=True, figsize=(12, 6))


    # Identify T² outliers
    t2_outliers, _ = model.outliers_from_t2(selected_components, alpha=0.99)
    if len(t2_outliers) > 0:
        print(f"T² outliers (99% confidence): {t2_outliers}")

    # SPE with chi-squared approximation
    spe_vals, spe_95, spe_99 = model.spe(selected_components, plot=True, figsize=(12, 6))
    plt.show()
    plt.close()
    print("Saved: advanced_pca_spe.png")

    # SPE with Jackson-Mudholkar approximation
    spe_jm_vals, spe_jm_95, spe_jm_99 = model.spe_jackson_mudholkar(
        selected_components, plot=True, figsize=(12, 6)
    )
    plt.show()
    plt.close()
    print("Saved: advanced_pca_spe_jackson_mudholkar.png")

    # Identify SPE outliers
    spe_outliers, _ = model.outliers_from_spe(selected_components, alpha=0.99)
    if len(spe_outliers) > 0:
        print(f"SPE outliers (99% confidence): {spe_outliers}")


    # Combine all outliers
    all_outliers = sorted(set(t2_outliers) | set(spe_outliers))

    if len(all_outliers) > 0:
        print(f"Analyzing variable contributions for samples: {all_outliers[:5]}")

        # Plot contributions for first few outliers
        for idx in all_outliers[:3]:
            print(idx)
            
            fig, _ = model.plot_contribs(indivs=idx, pc=2, figsize=(12, 6))
            # plt.savefig(f"advanced_pca_contributions_sample_{idx}.png", 
            #            dpi=150, bbox_inches='tight')
            # plt.close(fig)
            # print(f"Saved: advanced_pca_contributions_sample_{idx}.png")
    else:
        print("No significant outliers detected in this dataset.")


if __name__ == "__main__":
    main()
# Out:
# First 1 components have eigenvalues > 1
# Number of outliers detected: 0
# Saved: advanced_pca_spe.png
# Saved: advanced_pca_spe_jackson_mudholkar.png
# Number of outliers detected: 3
# SPE outliers (99% confidence): [ 15  60 131]
# Analyzing variable contributions for samples: [np.int64(15), np.int64(60), np.int64(131)]
# 15
# 60
# 131
